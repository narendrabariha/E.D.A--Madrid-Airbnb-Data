# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the data

# %%
df = pd.read_csv('listings.csv')

# %%
df.head()
# Out:
#       id                                      name    host_id host_name  \
# 0   6369  Rooftop terrace room ,  ensuite bathroom      13660     Simon
# 1  21853                      Bright and airy room      83531     Abdel
# 2  23001         Apartmento Arganzuela- Madrid Rio      82175     Jesus
# 3  24805                    Gran Via Studio Madrid  346366726         A
# 4  26825        Single Room whith private Bathroom     114340  Agustina
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0           Chamartín  Hispanoamérica  40.45724   -3.67688     Private room
# 1              Latina        Cármenes  40.40381   -3.74130     Private room
# 2          Arganzuela         Legazpi  40.38840   -3.69511  Entire home/apt
# 3              Centro     Universidad  40.42183   -3.70529  Entire home/apt
# 4          Arganzuela         Legazpi  40.38975   -3.69018     Private room
#
# ...

# %%
df.tail()
# Out:
#              id                                         name    host_id  \
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 19613    Belaid              Centro   Embajadores  40.40756   -3.69937
# 19614    Belaid            Chamberí    Gaztambide  40.43706   -3.71364
# 19615    Belaid            Chamberí      Arapiles  40.43857   -3.70715
# 19616    Belaid           Salamanca    Guindalera  40.43027   -3.66759
# 19617    Belaid            Chamberí      Arapiles  40.43484   -3.70667
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19618 entries, 0 to 19617
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19618 non-null  int64
#  1   name                            19615 non-null  object
#  2   host_id                         19618 non-null  int64
#  3   host_name                       19091 non-null  object
#  4   neighbourhood_group             19618 non-null  object
#  5   neighbourhood                   19618 non-null  object
#  6   latitude                        19618 non-null  float64
#  7   longitude                       19618 non-null  float64
#  8   room_type                       19618 non-null  object
#  9   price                           19618 non-null  int64
#  10  minimum_nights                  19618 non-null  int64
#  11  number_of_reviews               19618 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  1.961800e+04  1.961800e+04  19618.000000  19618.000000  19618.000000
# mean   2.912200e+07  1.312165e+08     40.420984     -3.694040    129.271740
# std    1.351839e+07  1.166790e+08      0.022627      0.028671    484.143545
# min    6.369000e+03  7.952000e+03     40.332210     -3.863910      0.000000
# 25%    1.903424e+07  2.765313e+07     40.409393     -3.707700     35.000000
# 50%    3.187506e+07  9.901898e+07     40.419735     -3.701120     58.000000
# 75%    4.090994e+07  2.256898e+08     40.430290     -3.685420    100.000000
# max    4.918779e+07  3.964281e+08     40.562740     -3.531900   9999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    19618.000000       19618.000000       13981.000000
# mean         6.586196          31.858803           1.125958
# std         33.286582          63.938997           1.348235
# ...

# %%
df.describe(include="O")
# Out:
#                       name host_name neighbourhood_group neighbourhood  \
# count                19615     19091               19618         19618
# unique               18793      3900                  21           128
# top     Habitación privada    Daniel              Centro   Embajadores
# freq                    22       255                8649          2318
#
#               room_type last_review
# count             19618       13981
# unique                4        1590
# top     Entire home/apt  2020-03-01
# freq              11314         359

# %% [markdown]
# # Exploratory Data Analysis

# %%
df["price"].mean()
# Out:
# 129.27174023855642

# %%
df["price"].min()
# Out:
# 0

# %%
df["price"].max()
# Out:
# 9999

# %%
 df["price"].median()
# Out:
# 58.0

# %%
df["price"].std()
# Out:
# 484.143544651945

# %%
df["price"].var()
# Out:
# 234394.97182814986

# %%
df["price"].skew()
# Out:
# 15.448872477202384

# %% [markdown]
# ## Numerical Analysis of Columns

# %% [markdown]
# ### What is the price group of most of the people are takinng loan for housing ?

# %% [markdown]
# #### what is the distibution of numeric column and where does most of the values lies?

# %% [markdown]
# ## Histogram plot

# %%
plt.figure(figsize=(6,3))
# Histogram plot
sns.histplot(df["price"],bins=30) 

plt.title("Histogram plot for price",y=1.02)
plt.xlabel("price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Distribution plot

# %%
plt.figure(figsize=(6,3))
# Distribution plot
sns.displot(df["price"],kind="kde") 
plt.title("Density plot for price",y=1.02)
plt.xlabel("price")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# ## Box plot

# %%
plt.figure(figsize=(6,3))
# Box plot
sns.boxplot(df["price"],orient="h") 

plt.title("Box plot for price",y=1.02)
plt.xlabel("price")
# plt.ylabel("")
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
plt.figure(figsize=(6,3))
# Violin Plot
sns.violinplot(df["price"],orient="h",color="chartreuse") 
sns.swarmplot( df["price"],size=0.3,orient="h")

plt.title("Violin plot for price",y=1.02)
plt.xlabel("price")
# plt.ylabel("")
plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 55.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(6, 3))

# Violin Plot
sns.violinplot(df["price"], orient="h", color="chartreuse")

# Swarm Plot
sns.swarmplot(df["price"], size=0.05, orient="h", color="black")

plt.title("Violin plot for price", y=1.02)
plt.xlabel("price")
plt.ylabel("")  # Add a label if needed

plt.show()

# %%
df["price"].quantile(0.10),df["price"].quantile(0.25),df["price"].quantile(0.50),df["price"].quantile(0.75),df["price"].quantile(0.90)
# Out:
# (21.0, 35.0, 58.0, 100.0, 191.0)

# %% [markdown]
# **price** column has a symmetrical distribution with skew 15.44 which is between 0.5 and 1 .
#
# - Density curve for price is centred around mean 129.27 with standard deviation of 484.14
# - Range of price value is from minimum 0 and maximum 9999
# - Most of the people are failling under price group of 100 - 500
# - 10% of people are of price 21.0 and below.
# - 25% of people are of price 35.0 and below.
# - 50% of people are of price 58.0 and below.
# - 75% of people are of price 100.0 and below.
# - 90% of people are of price 191.0and below.
# - price column has few extreme values toward higher price group 100 and above.
#
# price column could be a good predictor for calculated_host_listings_count and its relation with other columns should be explored further.

# %% [markdown]
# ## Categortical Analysis of Columns

# %% [markdown]
# How many unique values are in the column and What are they?

# %%
df["room_type"].nunique()
# Out:
# 4

# %%
df["room_type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
What is the room_type status of each gender , express it in percentprice?
# Out:
# Object `percentprice` not found.

# %%
df['room_type'].value_counts()
# Out:
# Entire home/apt    11314
# Private room        7809
# Shared room          329
# Hotel room           166
# Name: room_type, dtype: int64

# %%
plt.figure(figsize=(4,6))
# piechart
sizes = [11314,  7809, 329, 166]
plt.pie(sizes, labels=["Entire home/apt","Private room","Shared room ","Hotel room"], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
df['room_type'].value_counts(normalize=True)*100
# Out:
# Entire home/apt    57.671526
# Private room       39.805281
# Shared room         1.677031
# Hotel room          0.846162
# Name: room_type, dtype: float64

# %% [markdown]
# ## Countplot

# %%
plt.figure(figsize=(8,6))
# Countplot
sns.countplot(x=df["room_type"])

plt.title("Count plot for room_type",y=1.02)
plt.xlabel("room_type")
# plt.ylabel("")
plt.show()
plt.show()

# %%
df['room_type'].value_counts().sort_values()
# Out:
# Hotel room           166
# Shared room          329
# Private room        7809
# Entire home/apt    11314
# Name: room_type, dtype: int64

# %% [markdown]
# **room_type** column is having 4 uniques values and they are Hotel room,Shared room,Private room and Entire home/apt
#
# - no. of Hotel room are 166 and it is 0.84 % of data.
# - no. of Shared room are 329 and it is 1.672% of data.
# - no. of Private room  are 7809 and it is 39.80% of data.
# - no. of Entire home/apt  are 11314 and it is 57.67% of data.
#
# room_type column could have some impact of calculated_host_listings_count, so it would be logical to explore this further with other columns together.

# %% [markdown]
# ## Exploring host_name column

# %%
df['host_name'].value_counts().sort_values()
# Out:
# Monse        1
# Bikesh       1
# Lah          1
# Alejo        1
# Lucadia      1
#           ...
# Ana        186
# Maria      192
# Javier     230
# Carlos     231
# Daniel     255
# Name: host_name, Length: 3900, dtype: int64

# %% [markdown]
# ### What host_name are frequently occuring?

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Assuming you have a DataFrame named df with a 'host_name' column

# Join the 'host_name' column values into a single string
text = " ".join(df['host_name'].astype(str))

# Generate the word cloud
wordcloud = WordCloud().generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Combine Numerical and categorical columns for analysis

# %% [markdown]
# ## Exploring room_type and price
# One categorical and one numerical

# %% [markdown]
# ### What is the average  price of room_type ?

# %%
df.groupby(["room_type"])["price"].mean()
# Out:
# room_type
# Entire home/apt    161.384568
# Hotel room         343.855422
# Private room        80.116276
# Shared room         83.404255
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=df,x="room_type",y="price",errorbar=None)

plt.title("Bar plot for room_type and price",y=1.02)
plt.xlabel("room_type")
# plt.ylabel("price")
plt.show()

# %% [markdown]
# ### What is the number of people room_type ?

# %%
sns.displot(data=df, x="price", hue="room_type",multiple="stack",) # bins parmater to increase or dicrease granularity.

# %% [markdown]
# ## Exploring room_type Sex and price
# two categorical value and one numerical value

# %% [markdown]
# ### What is the average price of people room_type?

# %%
df.groupby(["room_type","neighbourhood_group"])["price"].mean()
# Out:
# room_type        neighbourhood_group
# Entire home/apt  Arganzuela             221.954545
#                  Barajas                122.365385
#                  Carabanchel            145.796226
#                  Centro                 149.163934
#                  Chamartín              125.557185
#                                            ...
# Shared room      Tetuán                  47.500000
#                  Usera                   71.750000
#                  Vicálvaro              200.000000
#                  Villa de Vallecas      100.000000
#                  Villaverde              31.923077
# Name: price, Length: 75, dtype: float64

# %%
sns.barplot(data=df,x="room_type",y="price", hue="neighbourhood_group",errorbar=None)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %% [markdown]
# ### What is the count of people room_type ?

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='neighbourhood_group', hue='room_type',)
plt.show()

# %% [markdown]
# ## Exploring room_type Pclass and price
# two categorical column and 1 numerical column

# %%
df.groupby(["room_type","neighbourhood_group"])["price"].mean()
# Out:
# room_type        neighbourhood_group
# Entire home/apt  Arganzuela             221.954545
#                  Barajas                122.365385
#                  Carabanchel            145.796226
#                  Centro                 149.163934
#                  Chamartín              125.557185
#                                            ...
# Shared room      Tetuán                  47.500000
#                  Usera                   71.750000
#                  Vicálvaro              200.000000
#                  Villa de Vallecas      100.000000
#                  Villaverde              31.923077
# Name: price, Length: 75, dtype: float64

# %%
sns.barplot(data=df,x="room_type",y="price", hue="neighbourhood_group",errorbar=None)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.palplot(sns.color_palette("husl"))

# %%
sns.barplot(data=df,x="price",y="room_type",orient="h",hue="neighbourhood_group",errorbar=None,palette="husl")
# Out:
# <Axes: xlabel='price', ylabel='room_type'>

# %% [markdown]
# ## Exploring price and minimum_nights
# Analysis of two numerical value

# %% [markdown]
# ### How is minimum_nights and price related? Does increase or decrease in one value impact other?

# %%
data = df[["price","minimum_nights"]].corr() #.corr() to get correlation
data
# Out:
#                  price  minimum_nights
# price           1.0000          0.0185
# minimum_nights  0.0185          1.0000

# %%
sns.heatmap(data,cmap= "RdYlGn", annot=True,linewidth=.5)
# Out:
# <Axes: >

# %%
# ScatterPlot
sns.scatterplot(data=df, x="price", y="minimum_nights",color="olive")
# Out:
# <Axes: xlabel='price', ylabel='minimum_nights'>

# %%
sns.regplot(data=df, x="price", y="minimum_nights",scatter_kws={"color":'teal'},line_kws={"color":'red'})
# Out:
# <Axes: xlabel='price', ylabel='minimum_nights'>

# %%
sns.lmplot(data=df, x="price", y="minimum_nights",scatter_kws={"color":'teal'},line_kws={"color":'red'})

# %% [markdown]
# ## Exploring price minimum_nights and room_type
# two numerical column and 1 categorical colum

# %%
What is the impact of price and minimum_nights on Survival?

# %%
sns.scatterplot(data=df, x="price", y="minimum_nights",hue="room_type")
plt.show()

# %%
sns.lmplot(data=df, x="price", y="minimum_nights",hue="room_type",line_kws={"color":'red'})
plt.show()

# %% [markdown]
# ## Exploring price minimum_nights and room_type Pclass
# two numerical column and two categorical colum

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="price", y="minimum_nights",hue="room_type",size="neighbourhood_group")
plt.show()

# %% [markdown]
# ## Explore all other Columns and different combination.

# %% [markdown]
# ### Bonus : Multi-plot grid for plotting conditional relationships.

# %%
g = sns.FacetGrid(data=df, col="availability_365", row="room_type",hue="calculated_host_listings_count",margin_titles=True, height=4,)
g.map(sns.scatterplot, "price", "minimum_nights")
plt.figure(figsize=(12,8))  
g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 g = sns.FacetGrid(data=df, col="availability_365", row="room_type",hue="calculated_host_listings_count",margin_titles=True, height=4,)
#       2 g.map(sns.scatterplot, "price", "minimum_nights")
#       3 plt.figure(figsize=(12,8))
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:526, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     523 # --- Make the axes look good
#     525 self.set_titles()
# --> 526 self.tight_layout()
#     528 if despine:
#     529     self.despine()
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
# ...

# %%
g = sns.FacetGrid(data=df, col="number_of_reviews", row="room_type",margin_titles=True, height=4,)
g.map_dataframe(sns.histplot, x="price")
g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 g = sns.FacetGrid(data=df, col="number_of_reviews", row="room_type",margin_titles=True, height=4,)
#       2 g.map_dataframe(sns.histplot, x="price")
#       3 g.add_legend()
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:526, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     523 # --- Make the axes look good
#     525 self.set_titles()
# --> 526 self.tight_layout()
#     528 if despine:
#     529     self.despine()
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
#     116 if self._tight_layout_pad is not None:
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Handling Duplicate data

# %%
df.shape
# Out:
# (19618, 16)

# %%
df.drop_duplicates().shape
# Out:
# (19618, 16)

# %%
df.drop_duplicates?

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.drop_duplicates().reset_index(drop=True)
# Out:
#              id                                         name    host_id  \
# 0          6369     Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                         Bright and airy room      83531
# 2         23001            Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                       Gran Via Studio Madrid  346366726
# 4         26825           Single Room whith private Bathroom     114340
# ...         ...                                          ...        ...
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# ...

# %%
df.drop_duplicates(keep='first')
# Out:
#              id                                         name    host_id  \
# 0          6369     Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                         Bright and airy room      83531
# 2         23001            Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                       Gran Via Studio Madrid  346366726
# 4         26825           Single Room whith private Bathroom     114340
# ...         ...                                          ...        ...
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# ...

# %%
df.drop_duplicates(keep='last')
# Out:
#              id                                         name    host_id  \
# 0          6369     Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                         Bright and airy room      83531
# 2         23001            Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                       Gran Via Studio Madrid  346366726
# 4         26825           Single Room whith private Bathroom     114340
# ...         ...                                          ...        ...
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# ...

# %% [markdown]
# ## 2. Handling Missing Values

# %%
df.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  latitude  \
# 0      False  False    False      False                False     False
# 1      False  False    False      False                False     False
# 2      False  False    False      False                False     False
# 3      False  False    False      False                False     False
# 4      False  False    False      False                False     False
# ...      ...    ...      ...        ...                  ...       ...
# 19613  False  False    False      False                False     False
# 19614  False  False    False      False                False     False
# 19615  False  False    False      False                False     False
# 19616  False  False    False      False                False     False
# 19617  False  False    False      False                False     False
#
#        longitude  price  minimum_nights  number_of_reviews  ...  \
# ...

# %%
df.shape , len(df)
# Out:
# ((17205, 146), 17205)

# %%
df.isnull().sum()
# Out:
# id                             0
# name                           3
# host_id                        0
# host_name                    459
# neighbourhood_group            0
#                             ...
# neighbourhood_Zofío            0
# room_type_Entire home/apt      0
# room_type_Hotel room           0
# room_type_Private room         0
# room_type_Shared room          0
# Length: 146, dtype: int64

# %%
df.isnull().sum()/len(df)
# Out:
# id                           0.000000
# name                         0.000174
# host_id                      0.000000
# host_name                    0.026678
# neighbourhood_group          0.000000
#                                ...
# neighbourhood_Zofío          0.000000
# room_type_Entire home/apt    0.000000
# room_type_Hotel room         0.000000
# room_type_Private room       0.000000
# room_type_Shared room        0.000000
# Length: 146, dtype: float64

# %% [markdown]
# - name column has  0.000153% missing values.
# - host_name column has 0.026863% of missing values.
# - last_review column has  0.287338% of missing values.
# - reviews_per_month column has 0.287338% of missing values.

# %% [markdown]
# # 3. Handling Outliers

# %%
Q1 = df['calculated_host_listings_count'].quantile(0.25)
Q1
# Out:
# 1.0

# %%
Q2 = df['calculated_host_listings_count'].quantile(0.50) 
Q2
# Out:
# 2.0

# %%
Q3 = df['calculated_host_listings_count'].quantile(0.75) 
Q3
# Out:
# 6.0

# %%
IQR = Q3-Q1
IQR
# Out:
# 5.0

# %%
mimimum_whisker = Q1 - (1.5*IQR)
mimimum_whisker
# Out:
# -6.5

# %%
maximum_whisker = Q3 + (1.5*IQR)
maximum_whisker
# Out:
# 13.5

# %%
sns.boxplot(x= df['calculated_host_listings_count'],color='teal')
# Out:
# <Axes: xlabel='calculated_host_listings_count'>

# %%
sns.violinplot(x= df['calculated_host_listings_count'],color='gold')
# Out:
# <Axes: xlabel='calculated_host_listings_count'>

# %%
import matplotlib.pyplot as plt


plt.boxplot(df['price'])
plt.show()


plt.boxplot(df['calculated_host_listings_count'])
plt.show()

# %%
df = df[df['price'] <= 160]

# %%
df[df['price'] > 160]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
median = df['calculated_host_listings_count'].median()

df.loc[df['calculated_host_listings_count'] > 100, 'calculated_host_listings_count'] = median

# %%
import matplotlib.pyplot as plt


plt.boxplot(df['price'])
plt.show()


plt.boxplot(df['calculated_host_listings_count'])
plt.show()

# %% [markdown]
# ## 4. Handling Categoirical Values

# %%
df[['neighbourhood','room_type']].head()
# Out:
#     neighbourhood        room_type
# 0  Hispanoamérica     Private room
# 1        Cármenes     Private room
# 2         Legazpi  Entire home/apt
# 3     Universidad  Entire home/apt
# 4         Legazpi     Private room

# %%
pd.get_dummies(df, columns=['neighbourhood','room_type'])
# Out:
#              id                                         name    host_id  \
# 0          6369     Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                         Bright and airy room      83531
# 2         23001            Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                       Gran Via Studio Madrid  346366726
# 4         26825           Single Room whith private Bathroom     114340
# ...         ...                                          ...        ...
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group  latitude  longitude  price  \
# ...

# %%
df = pd.get_dummies(df, columns=['neighbourhood','room_type'])
df
# Out:
#              id                                         name    host_id  \
# 0          6369     Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                         Bright and airy room      83531
# 2         23001            Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                       Gran Via Studio Madrid  346366726
# 4         26825           Single Room whith private Bathroom     114340
# ...         ...                                          ...        ...
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group  latitude  longitude  price  \
# ...

# %%
df.replace({0:False,1:True},inplace=True)

# %%
df.head()
# Out:
#       id                                      name    host_id host_name  \
# 0   6369  Rooftop terrace room ,  ensuite bathroom      13660     Simon
# 1  21853                      Bright and airy room      83531     Abdel
# 2  23001         Apartmento Arganzuela- Madrid Rio      82175     Jesus
# 3  24805                    Gran Via Studio Madrid  346366726         A
# 4  26825        Single Room whith private Bathroom     114340  Agustina
#
#   neighbourhood_group  latitude  longitude price minimum_nights  \
# 0           Chamartín  40.45724   -3.67688    60           True
# 1              Latina  40.40381   -3.74130    31              4
# 2          Arganzuela  40.38840   -3.69511    50             15
# 3              Centro  40.42183   -3.70529    92              5
# 4          Arganzuela  40.38975   -3.69018    26              2
#
#   number_of_reviews  ... neighbourhood_Vallehermoso neighbourhood_Valverde  \
# ...

# %%
 from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## 5 . Handling Numerical values

# %%
df.head()
# Out:
#       id                                      name    host_id host_name  \
# 0   6369  Rooftop terrace room ,  ensuite bathroom      13660     Simon
# 1  21853                      Bright and airy room      83531     Abdel
# 2  23001         Apartmento Arganzuela- Madrid Rio      82175     Jesus
# 3  24805                    Gran Via Studio Madrid  346366726         A
# 4  26825        Single Room whith private Bathroom     114340  Agustina
#
#   neighbourhood_group  latitude  longitude price minimum_nights  \
# 0           Chamartín  40.45724   -3.67688    60           True
# 1              Latina  40.40381   -3.74130    31              4
# 2          Arganzuela  40.38840   -3.69511    50             15
# 3              Centro  40.42183   -3.70529    92              5
# 4          Arganzuela  40.38975   -3.69018    26              2
#
#   number_of_reviews  ... neighbourhood_Vallehermoso neighbourhood_Valverde  \
# ...

# %%
sns.histplot(x= df['price'],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(x=df['calculated_host_listings_count'],kde=True)
# Out:
# <Axes: xlabel='calculated_host_listings_count', ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler ,MinMaxScaler
scaler = StandardScaler()
df[['price', 'calculated_host_listings_count']] = scaler.fit_transform(df[['price', 'calculated_host_listings_count']])
df
# Out:
#              id                                         name    host_id  \
# 0          6369     Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                         Bright and airy room      83531
# 2         23001            Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                       Gran Via Studio Madrid  346366726
# 4         26825           Single Room whith private Bathroom     114340
# ...         ...                                          ...        ...
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group  latitude  longitude     price  \
# ...
